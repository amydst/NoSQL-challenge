# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {
    'scores.Hygiene': {
        '$eq' : 20
    }
}

# Use count_documents to display the number of documents in the result
# establishments.count_documents(query)
count = establishments.count_documents(query)

print(f'Number of establishements found: {count} \n')

# Display the first document in the results using pprint

results = list(establishments.find(query,{}))

print("First result: \n")
pprint(results[0])
# Out:
# Number of establishements found: 41
#
# First result:
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('671d91872cc67627f2a95aff'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_20_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(hygiene_20_df.shape[0])

# Display the first 10 rows of the DataFrame
hygiene_20_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  671d91872cc67627f2a95aff   110681                  0
# 1  671d91872cc67627f2a95e7f   612039                  0
# 2  671d91872cc67627f2a96188   730933                  0
# 3  671d91872cc67627f2a9637d   172735                  0
# 4  671d91872cc67627f2a96381   172953                  0
# 5  671d91872cc67627f2a96d23   512854                  0
# 6  671d91872cc67627f2a96f43  1537089                  0
# 7  671d91872cc67627f2a9846f   155648                  0
# 8  671d91872cc67627f2a988b3  1012883                  0
# 9  671d91872cc67627f2a990c6   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
unique_values = establishments.distinct('AddressLine3')
print(unique_values)
# Out:
# ['', '1 - 2 Davy Road', '1 - 7 Commercial Road', '1 Dock Road', '1 Elmfield Park', '1 Hallsville Road', '1 High Street', '1 Robin Hood Lane', '1 St Nicholas Passage', '1 St Runwald Street', '1 Triangle Shopping Centre', '1 Western Gateway', '1-2 Sparrow Way', '1-5 Harvey Centre Approach', '10 - 12 Commercial Road', '10 Canterbury Road', '100 Third Avenue', '1000 Dockside Road', '103 - 107 York Road', '103 Maidstone Road', '105 Hopewell Drive', '106 Pattens Lane', '109 Tollgate Road', '11 Oxford Road', '11A North Hill', '123 Star Lane', '129-139 Layer Road', '13 Eridge Road', '13 High Street', '14 Fox Burrows Lane', '14 Turners Place', '14 Western Gateway', '143 Church Street', '147 Station Road', '15 Corys Road', '15 The Grove', '15A-16 New Road Avenue', '16 Victoria Road', '17 Market Buildings', '18 New Road Avenue', '186 High Street', '189 Romford Road', '1A Balfour Road', '1A Howard Road', '2 Agnes George Walk', '2 Bramwell Way', '2 Cromar Way', '2 Western Gateway', '20 Canning Ro
# ...

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={
    'LocalAuthorityName':{
        '$regex': 'London'
    },
    'RatingValue':{
        '$gte': 4
    }
}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)

print(f'Number of establishements found: {count} \n')

# # Display the first document in the results using pprint
results = list(establishments.find(query,{}))

print("First establishment: \n")
pprint(results[0])
# Out:
# Number of establishements found: 33
#
# First establishment:
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('671d91872cc67627f2a97519'),
# ...

# %%
# Convert the result to a Pandas DataFrame
london_gte_4 = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(london_gte_4.shape[0])

# Display the first 10 rows of the DataFrame
london_gte_4.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  671d91872cc67627f2a97519   621707                  0
# 1  671d91872cc67627f2a9783e  1130836                  0
# 2  671d91872cc67627f2a9838b   293783                  0
# 3  671d91872cc67627f2a99186  1315095                  0
# 4  671d91872cc67627f2a9918b   294474                  0
# 5  671d91882cc67627f2a99892   294900                  0
# 6  671d91882cc67627f2a9b9a3   293756                  0
# 7  671d91882cc67627f2a9bd69   878523                  0
# 8  671d91882cc67627f2a9bd83   293772                  0
# 9  671d91882cc67627f2a9bd84   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
lat_and_long = {
'geocode.latitude':1,
'geocode.longitude':1
}

result = establishments.find_one({'BusinessName': {'$eq':'Penang Flavours' }},lat_and_long)
latitude = result['geocode']['latitude']
longitude = result['geocode']['longitude']

query = {'RatingValue': 5, 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }

sort = [
    ('scores.Hygiene',1)
]

limit = 5

# Print the results
top_5_nearby = list(establishments.find(query).sort(sort).limit(limit))

pprint(top_5_nearby)
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('671d91882cc67627f2a9b352'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
# ...

# %%
# Convert result to Pandas DataFrame
top_5_nearby_df =pd.DataFrame(top_5_nearby)
top_5_nearby_df.head(5)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  671d91882cc67627f2a9b352   694609                  0
# 1  671d91882cc67627f2a9b374   695241                  0
# 2  671d91882cc67627f2a9b377   694478                  0
# 3  671d91882cc67627f2a9b32c   695223                  0
# 4  671d91882cc67627f2a9b33a  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000086506                    Atlantic Fish Bar
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                 Takeaway/sandwich shop            7844
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_query = {
    '$match':{
        'scores.Hygiene':0
    }
}

# 2. Groups the matches by Local Authority
group_query = {
    '$group':{
        '_id':'$LocalAuthorityName',
        'count': {
            '$sum': 1
        }
    }
}
# 3. Sorts the matches from highest to lowest
sort_data = {
    '$sort':{
        'count': -1
    }
}

pipeline = [match_query, group_query, sort_data]

# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
print("Number of rows found: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of rows found:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_00_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
number_authorities = hygiene_00_df.shape[0]
print(f'Number of Local Authorities is: {number_authorities}')
# Display the first 10 rows of the DataFrame
hygiene_00_df.head(10)
# Out:
# Number of Local Authorities is: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
